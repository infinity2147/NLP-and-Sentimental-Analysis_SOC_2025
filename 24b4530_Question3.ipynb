# %%
corpus = [
    {"text": "The sunset was breathtakingly beautiful.", "sentiment": 1},
    {"text": "I enjoyed every moment of the festival.", "sentiment": 1},
    {"text": "This novel is captivating and well-crafted.", "sentiment": 1},
    {"text": "The team’s performance was outstanding.", "sentiment": 1},
    {"text": "I love the cozy atmosphere of this café.", "sentiment": 1},
    {"text": "The new app is user-friendly and efficient.", "sentiment": 1},
    {"text": "Her speech was inspiring and heartfelt.", "sentiment": 1},
    {"text": "The vacation was relaxing and rejuvenating.", "sentiment": 1},
    {"text": "The food at this restaurant is delicious.", "sentiment": 1},
    {"text": "I’m thrilled with my new laptop’s speed.", "sentiment": 1},
    {"text": "The concert was an unforgettable experience.", "sentiment": 1},
    {"text": "The staff were friendly and helpful.", "sentiment": 1},
    {"text": "This movie is absolutely fantastic.", "sentiment": 1},
    {"text": "The garden is blooming with vibrant colors.", "sentiment": 1},
    {"text": "I had a wonderful time at the beach.", "sentiment": 1},
    {"text": "The customer service was exceptional.", "sentiment": 1},
    {"text": "The play was engaging and beautifully acted.", "sentiment": 1},
    {"text": "I’m excited about my new project.", "sentiment": 1},
    {"text": "The hotel room was clean and comfortable.", "sentiment": 1},
    {"text": "The event was well-organized and fun.", "sentiment": 1},
    {"text": "The service was slow and unprofessional.", "sentiment": -1},
    {"text": "This book is dull and poorly written.", "sentiment": -1},
    {"text": "The movie was a complete disappointment.", "sentiment": -1},
    {"text": "My phone keeps freezing constantly.", "sentiment": -1},
    {"text": "The food was bland and overpriced.", "sentiment": -1},
    {"text": "The event was chaotic and disorganized.", "sentiment": -1},
    {"text": "I’m frustrated with the constant delays.", "sentiment": -1},
    {"text": "The product broke after just one day.", "sentiment": -1},
    {"text": "The performance was lackluster and boring.", "sentiment": -1},
    {"text": "The hotel room was dirty and cramped.", "sentiment": -1},
    {"text": "The app crashes every time I use it.", "sentiment": -1},
    {"text": "The staff were rude and unhelpful.", "sentiment": -1},
    {"text": "The concert was a total letdown.", "sentiment": -1},
    {"text": "The meal was cold and tasteless.", "sentiment": -1},
    {"text": "I’m upset about the poor customer service.", "sentiment": -1},
    {"text": "The book’s plot was confusing and weak.", "sentiment": -1},
    {"text": "The experience was highly disappointing.", "sentiment": -1},
    {"text": "The software is buggy and unreliable.", "sentiment": -1},
    {"text": "The event was poorly planned and executed.", "sentiment": -1},
    {"text": "The delivery was late and incomplete.", "sentiment": -1}
]

# %% [markdown]
# pre process and vectorize

# %%
texts = []
label = []
for item in corpus:
    texts.append(item['text'])
    label.append(item['sentiment'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Train Naive Bayes & Logistic Regression

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

nb_model = MultinomialNB()
lr_model = LogisticRegression()

nb_model.fit(X_train, y_train)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# Predictions
nb_preds = nb_model.predict(X_test)
lr_preds = lr_model.predict(X_test)

# Function to evaluate
def evaluate(model_name, y_true, y_pred):
    print(f"\n📊 {model_name} Evaluation")
    print("Accuracy:", round(accuracy_score(y_true, y_pred), 2))
    print("F1 Score:", round(f1_score(y_true, y_pred), 2))
    print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))

evaluate("Naive Bayes", y_test, nb_preds)
evaluate("Logistic Regression", y_test, lr_preds)
# Out:
# 📊 Naive Bayes Evaluation
# Accuracy: 0.5
# F1 Score: 0.4
# Confusion Matrix:
#  [[4 1]
#  [5 2]]
#
# 📊 Logistic Regression Evaluation
# Accuracy: 0.58
# F1 Score: 0.44
# Confusion Matrix:
#  [[5 0]
#  [5 2]]
